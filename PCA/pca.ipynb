# %% [markdown]
# # EX1_PCA

# %% [markdown]
# #https://archive.ics.uci.edu/dataset/484/travel+reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tripadvisor_review.csv")

# %%
df
# Out:
#       User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0      User 1        0.93        1.80        2.29        0.62        0.80
# 1      User 2        1.02        2.20        2.66        0.64        1.42
# 2      User 3        1.22        0.80        0.54        0.53        0.24
# 3      User 4        0.45        1.80        0.29        0.57        0.46
# 4      User 5        0.51        1.20        1.18        0.57        1.54
# ..        ...         ...         ...         ...         ...         ...
# 975  User 976        0.74        1.12        0.30        0.53        0.88
# 976  User 977        1.25        0.92        1.12        0.38        0.78
# 977  User 978        0.61        1.32        0.67        0.43        1.30
# 978  User 979        0.93        0.20        0.13        0.43        0.30
# 979  User 980        0.93        0.56        1.13        0.51        1.34
#
#      Category 6  Category 7  Category 8  Category 9  Category 10
# ...

# %%
df = df.drop('User ID', axis=1)

# %%
df
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0          0.93        1.80        2.29        0.62        0.80        2.42
# 1          1.02        2.20        2.66        0.64        1.42        3.18
# 2          1.22        0.80        0.54        0.53        0.24        1.54
# 3          0.45        1.80        0.29        0.57        0.46        1.52
# 4          0.51        1.20        1.18        0.57        1.54        2.02
# ..          ...         ...         ...         ...         ...         ...
# 975        0.74        1.12        0.30        0.53        0.88        1.38
# 976        1.25        0.92        1.12        0.38        0.78        1.68
# 977        0.61        1.32        0.67        0.43        1.30        1.78
# 978        0.93        0.20        0.13        0.43        0.30        0.40
# 979        0.93        0.56        1.13        0.51        1.34        2.36
#
#      Category 7  Category 8  Category 9  Category 10
# ...

# %%
mean = np.mean(df,axis=0)

# %%
mean
# Out:
# Category 1     0.893194
# Category 2     1.352612
# Category 3     1.013306
# Category 4     0.532500
# Category 5     0.939735
# Category 6     1.842898
# Category 7     3.180939
# Category 8     2.835061
# Category 9     1.569439
# Category 10    2.799224
# dtype: float64

# %%
standardized_data = df-mean
standardized_data
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0      0.036806    0.447388    1.276694      0.0875   -0.139735    0.577102
# 1      0.126806    0.847388    1.646694      0.1075    0.480265    1.337102
# 2      0.326806   -0.552612   -0.473306     -0.0025   -0.699735   -0.302898
# 3     -0.443194    0.447388   -0.723306      0.0375   -0.479735   -0.322898
# 4     -0.383194   -0.152612    0.166694      0.0375    0.600265    0.177102
# ..          ...         ...         ...         ...         ...         ...
# 975   -0.153194   -0.232612   -0.713306     -0.0025   -0.059735   -0.462898
# 976    0.356806   -0.432612    0.106694     -0.1525   -0.159735   -0.162898
# 977   -0.283194   -0.032612   -0.343306     -0.1025    0.360265   -0.062898
# 978    0.036806   -1.152612   -0.883306     -0.1025   -0.639735   -1.442898
# 979    0.036806   -0.792612    0.116694     -0.0225    0.400265    0.517102
#
#      Category 7  Category 8  Category 9  Category 10
# ...

# %%
cov_matrix= np.cov(standardized_data ,rowvar=False)
#setting rowvar=False tells numpy that the variables are in the columns
#and it will compute the covariance matrix correctly by treating each column as a feature.

# %%
cov_matrix
# Out:
# array([[ 1.06871607e-01, -2.93467582e-02,  2.22037981e-03,
#          6.71733912e-03, -1.43691211e-02,  1.66048308e-02,
#         -3.19084447e-05,  9.00366054e-04, -5.63977872e-03,
#          5.32668779e-03],
#        [-2.93467582e-02,  2.28751903e-01,  1.64395672e-02,
#          1.76099081e-02,  2.50284772e-02,  3.82955886e-02,
#          4.11845490e-04, -1.04332551e-02,  1.27905380e-02,
#         -1.01082888e-02],
#        [ 2.22037981e-03,  1.64395672e-02,  6.21900805e-01,
#          1.34846782e-02,  9.71643101e-02,  1.51657110e-01,
#         -8.47266567e-04],
#        [ 2.60974309e-01,  4.34618282e-01,  1.92722360e-01,
#         -3.51185829e-01,  5.26876835e-01, -1.28304201e-01,
# ...

# %%
eigenvalues
# Out:
# array([7.54063530e-01, 3.14307339e-01, 2.20850270e-01, 1.29790314e-01,
#        1.22981527e-01, 9.54117647e-02, 7.32377910e-02, 4.58843057e-02,
#        1.68877487e-02, 1.42290999e-05])

# %%
top_eigenvectors = eigenvectors[:,:2]
top_eigenvectors
# Out:
# array([[ 0.00292433, -0.04330094],
#        [ 0.07383989,  0.38398947],
#        [ 0.84824271, -0.47996876],
#        [ 0.0528678 ,  0.12044576],
#        [ 0.26097431,  0.43461828],
#        [ 0.39896681,  0.61494583],
#        [ 0.00701843, -0.00112407],
#        [-0.0250407 ,  0.0170712 ],
#        [-0.01537942,  0.17868969],
#        [-0.20984158, -0.08078241]])

# %%
top_eigenvectors = eigenvectors[:,:3]
top_eigenvectors
# Out:
# array([[ 0.00292433, -0.04330094,  0.24492946],
#        [ 0.07383989,  0.38398947, -0.88035885],
#        [ 0.84824271, -0.47996876, -0.14111936],
#        [ 0.0528678 ,  0.12044576, -0.01408771],
#        [ 0.26097431,  0.43461828,  0.19272236],
#        [ 0.39896681,  0.61494583,  0.32081646],
#        [ 0.00701843, -0.00112407, -0.00107192],
#        [-0.0250407 ,  0.0170712 ,  0.05728797],
#        [-0.01537942,  0.17868969, -0.01323574],
#        [-0.20984158, -0.08078241, -0.03662473]])

# %%
pca_data = np.dot(standardized_data, top_eigenvectors)
print("\nPCA Reduced Data:")
print(pca_data)
# Out:
# PCA Reduced Data:
# [[ 1.39140784 -0.06325254 -0.40005047]
#  [ 2.22564886  0.66056077 -0.42539237]
#  [-0.67726766 -0.51264503  0.41372553]
#  ...
#  [-0.27318478  0.21082073  0.05201853]
#  [-1.50784123 -1.24834691  0.59030319]
#  [ 0.436563    0.11913389  0.95334309]]

# %%
top_eigenvectors = eigenvectors[:,:7]
top_eigenvectors
# Out:
# array([[ 2.92432831e-03, -4.33009399e-02,  2.44929459e-01,
#          8.97705512e-02, -6.18925850e-01, -5.42663025e-01,
#          4.35546047e-01],
#        [ 7.38398917e-02,  3.83989474e-01, -8.80358846e-01,
#         -5.42035218e-02, -1.71575789e-01, -1.64379455e-01,
#          4.25160405e-02],
#        [ 8.48242713e-01, -4.79968757e-01, -1.41119357e-01,
#          6.66457288e-02,  5.46783756e-02, -1.06609971e-01,
#          1.51979612e-02],
#        [ 5.28677969e-02,  1.20445761e-01, -1.40877065e-02,
#          9.44205927e-02, -3.05882252e-01,  4.77292289e-01,
#          5.15674869e-01],
#        [ 2.60974309e-01,  4.34618282e-01,  1.92722360e-01,
#         -3.51185829e-01,  5.26876835e-01, -1.28304201e-01,
#          5.22300102e-01],
#        [ 3.98966812e-01,  6.14945834e-01,  3.20816459e-01,
#          3.52377925e-02, -2.78816035e-01, -5.66172267e-02,
#         -4.97122330e-01],
#        [ 7.01843006e-03, -1.12406924e-03, -1.07191801e-03,
# ...

# %%
pca_data = np.dot(standardized_data, top_eigenvectors)
print("\nPCA Reduced Data:")
print(pca_data)
# Out:
# PCA Reduced Data:
# [[ 1.39140784 -0.06325254 -0.40005047 ... -0.27693074 -0.0029089
#   -0.19717927]
#  [ 2.22564886  0.66056077 -0.42539237 ... -0.28336852 -0.20717652
#   -0.1584527 ]
#  [-0.67726766 -0.51264503  0.41372553 ... -0.55338622  0.29983645
#   -0.1066071 ]
#  ...
#  [-0.27318478  0.21082073  0.05201853 ...  0.36344248  0.00308339
#   -0.00721489]
#  [-1.50784123 -1.24834691  0.59030319 ...  0.02598964  0.65676511
#    0.25536358]
#  [ 0.436563    0.11913389  0.95334309 ...  0.05210221  0.29177297
#   -0.06882682]]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], color='blue', edgecolor='k', s=100)
for i, txt in enumerate(['A', 'B', 'C', 'D', 'E']):
    plt.annotate(txt, (pca_data[i, 0], pca_data[i, 1]), fontsize=12)
plt.title("PCA Result (2 Components)", fontsize=16)
plt.xlabel("Principal Component 1", fontsize=12)
plt.ylabel("Principal Component 2", fontsize=12)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))  # Adjust figure size if needed
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pca_data[:, 0], pca_data[:, 1], pca_data[:, 2], 
           color='blue', edgecolor='k', s=100)

for i, txt in enumerate(['A', 'B', 'C', 'D', 'E']):
    ax.text(pca_data[i, 0], pca_data[i, 1], pca_data[i, 2], txt, 
            fontsize=12)

ax.set_title("PCA Result (3 Components)", fontsize=16)
ax.set_xlabel("Principal Component 1", fontsize=12)
ax.set_ylabel("Principal Component 2", fontsize=12)
ax.set_zlabel("Principal Component 3", fontsize=12)

plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Assuming 'standardized_data' is your standardized data
pca = PCA().fit(standardized_data)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Elbow Plot for PCA')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Assuming 'standardized_data' is your standardized data
pca = PCA().fit(standardized_data)  # Fit PCA without specifying n_components initially

# Calculate cumulative explained variance
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Find the number of components that explain a desired amount of variance (e.g., 95%)
n_components = np.argmax(cumulative_variance >= 0.95) + 1

# %%
n_components
# Out:
# 7

# %%
pca = PCA(n_components=n_components)  # Use the n_components found above
pca_data = pca.fit_transform(standardized_data)

# %%
pca_data
# Out:
# array([[ 1.39140784, -0.06325254,  0.40005047, ...,  0.27693074,
#         -0.0029089 , -0.19717927],
#        [ 2.22564886,  0.66056077,  0.42539237, ...,  0.28336852,
#         -0.20717652, -0.1584527 ],
#        [-0.67726766, -0.51264503, -0.41372553, ...,  0.55338622,
#          0.29983645, -0.1066071 ],
#        ...,
#        [-0.27318478,  0.21082073, -0.05201853, ..., -0.36344248,
#          0.00308339, -0.00721489],
#        [-1.50784123, -1.24834691, -0.59030319, ..., -0.02598964,
#          0.65676511,  0.25536358],
#        [ 0.436563  ,  0.11913389, -0.95334309, ..., -0.05210221,
#          0.29177297, -0.06882682]])
